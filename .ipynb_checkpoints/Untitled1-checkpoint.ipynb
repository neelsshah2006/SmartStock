# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('./data/train.csv')
store = pd.read_csv('./data/store.csv')

# %%
data = train.merge(store, on='Store', how='left')
data['StateHoliday'] = data['StateHoliday'].astype(str)

# %%
data = data.drop(columns=['Promo2', 'Promo2SinceWeek', "Promo2SinceYear", "PromoInterval", 'CompetitionOpenSinceMonth'])
data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceYear
# 0                    2008.0
# 1                    2007.0
# 2                    2006.0
# 3                    2009.0
# 4                    2015.0

# %%
data = data[data['Open'] == 1]
data = data[data['Sales'] > 0]

data['Date'] = pd.to_datetime(data['Date'])

data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data['Day'] = data['Date'].dt.day
data['WeekOfYear'] = data['Date'].dt.isocalendar().week.astype(int)

data['CompetitionDistance'] = data['CompetitionDistance'].fillna(
    data['CompetitionDistance'].median()
)

data = data.fillna(0)

# %%
for col in ['StoreType','Assortment','StateHoliday']:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# %%
data = data.sort_values(['Store','Date'])

# %%
data['Average_Sales_7'] = (
    data.groupby('Store')['Sales']
    .transform(lambda x: x.rolling(7).mean())
)

data['Demand_Std_7'] = (
    data.groupby('Store')['Sales']
    .transform(lambda x: x.rolling(7).std())
)

data['Average_Sales_30'] = (
    data.groupby('Store')['Sales']
    .transform(lambda x: x.rolling(30).mean())
)

data['Demand_Std_30'] = (
    data.groupby('Store')['Sales']
    .transform(lambda x: x.rolling(30).std())
)

# %%
data = data.fillna(0)

# %%
data.head()
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1014980      1          3 2013-01-02   5530        668     1      0
# 1013865      1          4 2013-01-03   4327        578     1      0
# 1012750      1          5 2013-01-04   4486        619     1      0
# 1011635      1          6 2013-01-05   4997        635     1      0
# 1009405      1          1 2013-01-07   7176        785     1      1
#
#          StateHoliday  SchoolHoliday  StoreType  ...  CompetitionDistance  \
# 1014980             0              1          2  ...               1270.0
# 1013865             0              1          2  ...               1270.0
# 1012750             0              1          2  ...               1270.0
# 1011635             0              1          2  ...               1270.0
# 1009405             0              1          2  ...               1270.0
#
#          CompetitionOpenSinceYear  Year  Month  Day  WeekOfYear  \
# 1014980                    2008.0  2013      1    2           1
# 1013865                    2008.0  2013      1    3           1
# 1012750                    2008.0  2013      1    4           1
# 1011635                    2008.0  2013      1    5           1
# 1009405                    2008.0  2013      1    7           2
#
#          Average_Sales_7  Demand_Std_7  Average_Sales_30  Demand_Std_30
# 1014980              0.0           0.0               0.0            0.0
# 1013865              0.0           0.0               0.0            0.0
# 1012750              0.0           0.0               0.0            0.0
# 1011635              0.0           0.0               0.0            0.0
# 1009405              0.0           0.0               0.0            0.0
#
# [5 rows x 21 columns]

# %%
features = [
    'Store','DayOfWeek','Promo','SchoolHoliday',
    'StateHoliday','Year','Month','Day','WeekOfYear',
    'CompetitionDistance','StoreType','Assortment',
    'Average_Sales_7', 'Average_Sales_30', 'Demand_Std_7', 'Demand_Std_30'
]

# %%
X = data[features]
y = data['Sales']

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.4, shuffle=False
)

# %%
xgb_model = xgb.XGBRegressor(
    n_estimators=500,
    max_depth=8,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgb_model.predict(X_val)

print("Forecast MAPE:", mean_absolute_percentage_error(y_val, y_pred))
# Out:
# Forecast MAPE: 0.08506277948617935

# %%
val_df = data.copy()[-337736:]
val_df = val_df.drop(columns=['Sales'])
val_df
# Out:
#         Store  DayOfWeek       Date  Customers  Open  Promo  StateHoliday  \
# 610904    670          2 2013-12-31        548     1      0             0
# 608674    670          4 2014-01-02        673     1      0             0
# 607559    670          5 2014-01-03        677     1      0             0
# 606444    670          6 2014-01-04        551     1      0             0
# 603099    670          2 2014-01-07       1021     1      1             0
# ...       ...        ...        ...        ...   ...    ...           ...
# 5574     1115          1 2015-07-27        608     1      1             0
# 4459     1115          2 2015-07-28        500     1      1             0
# 3344     1115          3 2015-07-29        473     1      1             0
# 2229     1115          4 2015-07-30        502     1      1             0
# 1114     1115          5 2015-07-31        538     1      1             0
#
#         SchoolHoliday  StoreType  Assortment  CompetitionDistance  \
# 610904              1          0           0               2060.0
# 608674              1          0           0               2060.0
# 607559              1          0           0               2060.0
# 606444              0          0           0               2060.0
# 603099              0          0           0               2060.0
# ...               ...        ...         ...                  ...
# 5574                1          3           2               5350.0
# 4459                1          3           2               5350.0
# 3344                1          3           2               5350.0
# 2229                1          3           2               5350.0
# 1114                1          3           2               5350.0
#
#         CompetitionOpenSinceYear  Year  Month  Day  WeekOfYear  \
# 610904                       0.0  2013     12   31           1
# 608674                       0.0  2014      1    2           1
# 607559                       0.0  2014      1    3           1
# 606444                       0.0  2014      1    4           1
# 603099                       0.0  2014      1    7           2
# ...                          ...   ...    ...  ...         ...
# 5574                         0.0  2015      7   27          31
# 4459                         0.0  2015      7   28          31
# 3344                         0.0  2015      7   29          31
# 2229                         0.0  2015      7   30          31
# 1114                         0.0  2015      7   31          31
#
#         Average_Sales_7  Demand_Std_7  Average_Sales_30  Demand_Std_30
# 610904      6929.857143   2286.075854       7461.533333    2053.043859
# 608674      6664.000000   2278.251376       7448.466667    2061.814764
# 607559      5938.714286   1203.510935       7464.333333    2048.073129
# 606444      5932.857143   1210.063969       7421.800000    2091.589206
# 603099      6579.428571   2377.731402       7634.933333    2150.900981
# ...                 ...           ...               ...            ...
# 5574        6582.000000   1914.426372       6807.466667    1626.754686
# 4459        6869.142857   1976.829653       6905.333333    1612.289149
# 3344        7238.714286   1820.968214       6978.600000    1594.327003
# 2229        7676.285714   1649.139545       7091.600000    1570.309669
# 1114        8037.714286   1531.962109       7195.966667    1568.295022
#
# [337736 rows x 20 columns]

# %%
val_df['Actual'] = y_val.values
val_df['Predicted'] = y_pred

val_df['Error'] = val_df['Actual'] - val_df['Predicted']
val_df['APE'] = abs(val_df['Error']) / (val_df['Actual'] + 1)

val_df['Rolling_MAPE'] = (
    val_df.groupby('Store')['APE']
    .transform(lambda x: x.rolling(7).mean())
)

val_df['Error_Std'] = (
    val_df.groupby('Store')['Error']
    .transform(lambda x: x.rolling(7).std())
)

val_df['Forecast_Confidence'] = 1 / (1 + val_df['Error_Std'])

val_df = val_df.fillna(0)

# %%
val_df['Past_Promo_Sales'] = (
    val_df['Actual']
    .where(val_df['Promo'] == 1)
    .groupby(val_df['Store'])
    .transform(lambda x: x.shift(1).expanding().mean())
)

val_df['Past_Normal_Sales'] = (
    val_df['Actual']
    .where(val_df['Promo'] == 0)
    .groupby(val_df['Store'])
    .transform(lambda x: x.shift(1).expanding().mean())
)

val_df['Expected_Uplift'] = (
    (val_df['Past_Promo_Sales'] - val_df['Past_Normal_Sales']) /
    (val_df['Past_Normal_Sales'] + 1)
)

val_df['Current_Uplift'] = (
    (val_df['Actual'] - val_df['Average_Sales_7']) /
    (val_df['Average_Sales_7'] + 1)
)

val_df['Promotion_Abnormality'] = (
    val_df['Current_Uplift'] -
    val_df['Expected_Uplift']
)

# %%
val_df["Volatility_Ratio"] = (
    val_df["Demand_Std_7"] / val_df["Average_Sales_7"]
).replace([np.inf, -np.inf], 0).fillna(0)

val_df["Volatility_Change"] = (
    val_df["Demand_Std_7"] / val_df["Demand_Std_30"]
).replace([np.inf, -np.inf], 0).fillna(0)

val_df["Trend_Shift"] = (
    val_df["Average_Sales_7"] - val_df["Average_Sales_30"]
)

val_df["Relative_Error"] = (
    np.abs(val_df["Error"]) / val_df["Average_Sales_7"]
).replace([np.inf, -np.inf], 0).fillna(0)

val_df["Prediction_Deviation_Ratio"] = (
    (val_df["Predicted"] - val_df["Average_Sales_7"]) / val_df["Average_Sales_7"]
).replace([np.inf, -np.inf], 0).fillna(0)

val_df["Promo_Risk"] = (
    val_df["Promo"] * val_df["Volatility_Ratio"]
)

val_df["Confidence_Error_Gap"] = (
    val_df["Forecast_Confidence"] * val_df["APE"]
)

# %%
val_df["Days_Since_Last_Promo"] = (
    val_df.groupby("Store")["Promo"]
    .apply(lambda x: (~x.astype(bool)).cumsum() - 
                     (~x.astype(bool)).cumsum().where(x == 1).ffill().fillna(0))
    .reset_index(level=0, drop=True)
)

# %%
val_df["Demand_Shock_Score"] = (
    val_df["Actual"] - val_df["Average_Sales_30"]
) / (val_df["Demand_Std_30"] + 1)

val_df["Demand_Shock"] = (
    val_df["Demand_Shock_Score"] > 2
).astype(int)

# %%
val_df["Demand_Momentum"] = (
    val_df["Average_Sales_7"] - val_df["Average_Sales_30"]
) / (val_df["Average_Sales_30"] + 1)

val_df["Demand_Acceleration"] = (
    val_df.groupby("Store")["Actual"]
    .diff()
    .diff()
)

val_df["Demand_Spike"] = (
    val_df["Actual"] >
    val_df["Average_Sales_30"] + 2 * val_df["Demand_Std_30"]
).astype(int)

val_df["Demand_Drop"] = (
    val_df["Actual"] <
    val_df["Average_Sales_30"] - 2 * val_df["Demand_Std_30"]
).astype(int)

# %%
val_df["Forecast_Uncertainty"] = (
    val_df["Demand_Std_7"] /
    (val_df["Predicted"] + 1)
)

# %%
val_df["Is_Holiday"] = (
    (val_df["SchoolHoliday"] == 1) |
    (val_df["StateHoliday"] != 0)
).astype(int)

val_df["Holiday_Proximity"] = (
    val_df.groupby("Store")["Is_Holiday"]
    .transform(lambda x: x.rolling(7, min_periods=1).max())
)

# %%
val_df["Relative_Error"] = np.abs(val_df["Error"]) / (val_df["Actual"] + 1)

# %%
val_df["Days_Until_Next_Promo"] = (
    val_df.groupby(["Store"])["Promo"]
    .transform(lambda x: x[::-1].cumsum()[::-1])
)

# %%
val_df["Days_To_Month_End"] = (
    val_df["Date"].dt.daysinmonth - val_df["Date"].dt.day
)

# %%
val_df["Sales_per_Customer"] = (
    val_df["Actual"] / (val_df["Customers"] + 1)
)

val_df["Customer_Growth"] = (
    val_df.groupby("Store")["Customers"]
    .pct_change()
)

val_df["Customer_Volatility_7"] = (
    val_df.groupby("Store")["Customers"]
    .rolling(7)
    .std()
    .reset_index(level=0, drop=True)
)

# %%
val_df["Traffic_Spike"] = (
    val_df["Customers"] >
    val_df["Customers"].rolling(30).mean() * 1.5
).astype(int)

# %%
val_df["Week_sin"] = np.sin(2 * np.pi * val_df["WeekOfYear"] / 52)
val_df["Week_cos"] = np.cos(2 * np.pi * val_df["WeekOfYear"] / 52)

val_df["Day_sin"] = np.sin(2 * np.pi * val_df["DayOfWeek"] / 7)
val_df["Day_cos"] = np.cos(2 * np.pi * val_df["DayOfWeek"] / 7)

# %%
val_df["Promo_Demand_Risk"] = val_df["Promo"] * val_df["Volatility_Ratio"]
val_df["Forecast_Risk"] = (1 - val_df["Forecast_Confidence"]) * val_df["Volatility_Ratio"]

# %%
val_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceYear', 'Year', 'Month',
#        'Day', 'WeekOfYear', 'Average_Sales_7', 'Demand_Std_7',
#        'Average_Sales_30', 'Demand_Std_30', 'Actual', 'Predicted', 'Error',
#        'APE', 'Rolling_MAPE', 'Error_Std', 'Forecast_Confidence',
#        'Past_Promo_Sales', 'Past_Normal_Sales', 'Expected_Uplift',
#        'Current_Uplift', 'Promotion_Abnormality', 'Volatility_Ratio',
#        'Volatility_Change', 'Trend_Shift', 'Relative_Error',
#        'Prediction_Deviation_Ratio', 'Promo_Risk', 'Confidence_Error_Gap',
#        'Days_Since_Last_Promo', 'Demand_Shock_Score', 'Demand_Shock',
#        'Demand_Momentum', 'Demand_Acceleration', 'Demand_Spike', 'Demand_Drop',
#        'Forecast_Uncertainty', 'Is_Holiday', 'Holiday_Proximity',
#        'Days_Until_Next_Promo', 'Days_To_Month_End', 'Sales_per_Customer',
#        'Customer_Growth', 'Customer_Volatility_7', 'Traffic_Spike', 'Week_sin',
#        'Week_cos', 'Day_sin', 'Day_cos', 'Promo_Demand_Risk', 'Forecast_Risk'],
#       dtype='object')

# %%
len(val_df.columns)
# Out:
# 61

# %%
forecast_risk = (
    0.5 * np.clip(val_df["Relative_Error"], 0, 1) +
    0.3 * np.clip(val_df["Rolling_MAPE"], 0, 1) +
    0.2 * np.clip(val_df["Prediction_Deviation_Ratio"] / 3, 0, 1)
)

demand_risk = (
    0.4 * np.clip(val_df["Demand_Shock_Score"] / 3, 0, 1) +
    0.3 * np.clip(val_df["Volatility_Ratio"] / 2, 0, 1) +
    0.3 * val_df["Demand_Spike"]
)

promo_risk = (
    0.5 * np.clip(val_df["Promotion_Abnormality"] / 2, 0, 1) +
    0.5 * np.clip(val_df["Promo_Risk"], 0, 1)
)

confidence_risk = (
    0.6 * (1 - val_df["Forecast_Confidence"]) +
    0.4 * np.clip(val_df["Forecast_Uncertainty"], 0, 1)
)

holiday_risk = (
    0.7 * val_df["Is_Holiday"] +
    0.3 * (val_df["Holiday_Proximity"] < 3).astype(int)
)

# %%
risk_score = (
    0.45 * forecast_risk +
    0.25 * demand_risk +
    0.15 * promo_risk +
    0.10 * confidence_risk +
    0.05 * holiday_risk
)

risk_score = (risk_score - risk_score.min()) / (risk_score.max() - risk_score.min())

# %%
prob_review = 1 / (1 + np.exp(-10 * (risk_score - 0.55)))

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(risk_score, bins=50)
plt.show()

# %%
noise = np.random.normal(0, 0.05, len(val_df))
prob_review = np.clip(prob_review + noise, 0, 1)
prob_review = np.nan_to_num(prob_review, nan=0.5)
prob_review = np.clip(prob_review, 0.001, 0.999)

# %%
val_df["HALT_Label"] = np.random.binomial(1, prob_review)

# %%
val_df['HALT_Label'].value_counts()
# Out:
# HALT_Label
# 0    323533
# 1     14203
# Name: count, dtype: int64

# %%
val_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceYear', 'Year', 'Month',
#        'Day', 'WeekOfYear', 'Average_Sales_7', 'Demand_Std_7',
#        'Average_Sales_30', 'Demand_Std_30', 'Actual', 'Predicted', 'Error',
#        'APE', 'Rolling_MAPE', 'Error_Std', 'Forecast_Confidence',
#        'Past_Promo_Sales', 'Past_Normal_Sales', 'Expected_Uplift',
#        'Current_Uplift', 'Promotion_Abnormality', 'Volatility_Ratio',
#        'Volatility_Change', 'Trend_Shift', 'Relative_Error',
#        'Prediction_Deviation_Ratio', 'Promo_Risk', 'Confidence_Error_Gap',
#        'Days_Since_Last_Promo', 'Demand_Shock_Score', 'Demand_Shock',
#        'Demand_Momentum', 'Demand_Acceleration', 'Demand_Spike', 'Demand_Drop',
#        'Forecast_Uncertainty', 'Is_Holiday', 'Holiday_Proximity',
#        'Days_Until_Next_Promo', 'Days_To_Month_End', 'Sales_per_Customer',
#        'Customer_Growth', 'Customer_Volatility_7', 'Traffic_Spike', 'Week_sin',
#        'Week_cos', 'Day_sin', 'Day_cos', 'Promo_Demand_Risk', 'Forecast_Risk',
#        'HALT_Label'],
#       dtype='object')

# %%
halt_features = [
    "Forecast_Confidence",
    "Forecast_Uncertainty",
    "Promotion_Abnormality",
    "Promo_Risk",
    "Past_Promo_Sales",
    "Past_Normal_Sales",
    "Days_Since_Last_Promo",
    "Volatility_Ratio",
    "Volatility_Change",
    "Trend_Shift",
    'Demand_Shock_Score',
    'Demand_Spike', 
    'Demand_Drop',
    "Demand_Momentum",
    "Promo_Demand_Risk",
    "Forecast_Risk"
]

# %%
X_halt = val_df[halt_features]
y_halt = val_df['HALT_Label']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_halt, y_halt, test_size=0.4, random_state=42, stratify=y_halt
)

# %%
halt_model = xgb.XGBClassifier(
    n_estimators=1200,
    max_depth=6,
    learning_rate=0.01,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=SMOTE,
    eval_metric="logloss",
    random_state=42
)

# %%
halt_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = halt_model.predict(X_test)
y_prob = halt_model.predict_proba(X_test)[:,1]

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# [[129017    397]
#  [  5227    454]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98    129414
#            1       0.53      0.08      0.14      5681
#
#     accuracy                           0.96    135095
#    macro avg       0.75      0.54      0.56    135095
# weighted avg       0.94      0.96      0.94    135095
#
# ROC-AUC: 0.683055383604831

# %%
importance = pd.Series(
    halt_model.feature_importances_,
    index=halt_features
).sort_values(ascending=True)

print(importance)
# Out:
# Trend_Shift              0.004652
# Days_Since_Last_Promo    0.004665
# Volatility_Change        0.004904
# Promo_Demand_Risk        0.004928
# Demand_Momentum          0.005048
# Promo_Risk               0.005302
# Forecast_Uncertainty     0.005347
# Past_Normal_Sales        0.005424
# Promotion_Abnormality    0.006316
# Volatility_Ratio         0.006574
# Forecast_Confidence      0.007817
# Forecast_Risk            0.008540
# Past_Promo_Sales         0.008799
# Demand_Drop              0.012804
# Demand_Shock_Score       0.019138
# Demand_Spike             0.889745
# dtype: float32

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9583700359006625
